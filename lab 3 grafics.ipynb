# %%
import pandas as pd 
from pathlib import Path

def get_data_df():
    df = pd.read_csv(r'D:\anaconda\lab 3\household_power_consumption.txt', sep = ';' )
    df.columns = ['Date', 'Time', 'GAP', 'GRP', 'Voltage', 'GI', 'SM1', 'SM2', 'SM3']    
    df = df.loc[(df['GAP'] != '?')]
    cols = ['GAP', 'GRP', 'Voltage', 'GI', 'SM1', 'SM2', 'SM3']
    df[cols] = df[cols].apply(pd.to_numeric)
    
    return df

df = get_data_df()

print(df)
# Out:
# D:\anaconda\lib\site-packages\IPython\core\interactiveshell.py:3254: DtypeWarning: Columns (2,3,4,5,6,7) have mixed types.Specify dtype option on import or set low_memory=False.
#   if (await self.run_code(code, result,  async_=asy)):
#                Date      Time    GAP    GRP  Voltage    GI  SM1  SM2   SM3
# 0        16/12/2006  17:24:00  4.216  0.418   234.84  18.4  0.0  1.0  17.0
# 1        16/12/2006  17:25:00  5.360  0.436   233.63  23.0  0.0  1.0  16.0
# 2        16/12/2006  17:26:00  5.374  0.498   233.29  23.0  0.0  2.0  17.0
# 3        16/12/2006  17:27:00  5.388  0.502   233.74  23.0  0.0  1.0  17.0
# 4        16/12/2006  17:28:00  3.666  0.528   235.68  15.8  0.0  1.0  17.0
# ...             ...       ...    ...    ...      ...   ...  ...  ...   ...
# 2075254  26/11/2010  20:58:00  0.946  0.000   240.43   4.0  0.0  0.0   0.0
# 2075255  26/11/2010  20:59:00  0.944  0.000   240.00   4.0  0.0  0.0   0.0
# ...

# %%
import pandas as pd 
import numpy as np

def get_data_arr():
    
    df = pd.read_csv(r'D:\anaconda\lab 3\household_power_consumption.txt', sep = ';' )
    df.columns = ['Date', 'Time', 'GAP', 'GRP', 'Voltage', 'GI', 'SM1', 'SM2', 'SM3']    
    df = df.loc[(df['GAP'] != '?')]
    cols = ['GAP', 'GRP', 'Voltage', 'GI', 'SM1', 'SM2', 'SM3']
    df[cols] = df[cols].apply(pd.to_numeric)
    array = df.values
    
    np.set_printoptions(edgeitems=5)
    
    return array

array = get_data_arr()

print (array)
# Out:
# D:\anaconda\lib\site-packages\IPython\core\interactiveshell.py:3254: DtypeWarning: Columns (2,3,4,5,6,7) have mixed types.Specify dtype option on import or set low_memory=False.
#   if (await self.run_code(code, result,  async_=asy)):
# [['16/12/2006' '17:24:00' 4.216 0.418 234.84 18.4 0.0 1.0 17.0]
#  ['16/12/2006' '17:25:00' 5.36 0.436 233.63 23.0 0.0 1.0 16.0]
#  ['16/12/2006' '17:26:00' 5.374 0.498 233.29 23.0 0.0 2.0 17.0]
#  ['16/12/2006' '17:27:00' 5.388 0.502 233.74 23.0 0.0 1.0 17.0]
#  ['16/12/2006' '17:28:00' 3.6660000000000004 0.528 235.68 15.8 0.0 1.0
#   17.0]
#  ...
#  ['26/11/2010' '20:58:00' 0.946 0.0 240.43 4.0 0.0 0.0 0.0]
#  ['26/11/2010' '20:59:00' 0.9440000000000001 0.0 240.0 4.0 0.0 0.0 0.0]
#  ['26/11/2010' '21:00:00' 0.938 0.0 239.82 3.8 0.0 0.0 0.0]
#  ['26/11/2010' '21:01:00' 0.934 0.0 239.7 3.8 0.0 0.0 0.0]
#  ['26/11/2010' '21:02:00' 0.932 0.0 239.55 3.8 0.0 0.0 0.0]]

# %%
def filters_1_df(df): 
    df_filtered_1 = df.loc[(df['GAP'] > 5)]
    
    return df_filtered_1


filters_1_df(df)
# Out:
#                Date      Time    GAP    GRP  Voltage    GI   SM1   SM2   SM3
# 1        16/12/2006  17:25:00  5.360  0.436   233.63  23.0   0.0   1.0  16.0
# 2        16/12/2006  17:26:00  5.374  0.498   233.29  23.0   0.0   2.0  17.0
# 3        16/12/2006  17:27:00  5.388  0.502   233.74  23.0   0.0   1.0  17.0
# 11       16/12/2006  17:35:00  5.412  0.470   232.78  23.2   0.0   1.0  17.0
# 12       16/12/2006  17:36:00  5.224  0.478   232.99  22.4   0.0   1.0  16.0
# ...             ...       ...    ...    ...      ...   ...   ...   ...   ...
# 2069356  22/11/2010  18:40:00  5.408  0.150   231.50  23.6  48.0   0.0   0.0
# 2069357  22/11/2010  18:41:00  5.528  0.144   232.48  24.6  53.0   0.0   0.0
# 2071586  24/11/2010  07:50:00  5.172  0.050   235.18  22.0   0.0  38.0  17.0
# 2071587  24/11/2010  07:51:00  5.750  0.000   234.40  24.6   0.0  39.0  17.0
# 2072997  25/11/2010  07:21:00  5.074  0.240   238.55  21.4   1.0   2.0  18.0
#
# [17547 rows x 9 columns]

# %%
def filter_1_arr(array):
    
    array_filtered_1 = array[array[:,2] > 5] #GAP > 5
    
    return array_filtered_1 

print(filter_1_arr(array))
# Out:
# [['16/12/2006' '17:25:00' 5.36 0.436 233.63 23.0 0.0 1.0 16.0]
#  ['16/12/2006' '17:26:00' 5.374 0.498 233.29 23.0 0.0 2.0 17.0]
#  ['16/12/2006' '17:27:00' 5.388 0.502 233.74 23.0 0.0 1.0 17.0]
#  ['16/12/2006' '17:35:00' 5.412000000000001 0.47 232.78 23.2 0.0 1.0 17.0]
#  ['16/12/2006' '17:36:00' 5.224 0.478 232.99 22.4 0.0 1.0 16.0]
#  ...
#  ['22/11/2010' '18:40:00' 5.4079999999999995 0.15 231.5 23.6 48.0 0.0 0.0]
#  ['22/11/2010' '18:41:00' 5.528 0.14400000000000002 232.48 24.6 53.0 0.0
#   0.0]
#  ['24/11/2010' '07:50:00' 5.172000000000001 0.05 235.18 22.0 0.0 38.0
#   17.0]
#  ['24/11/2010' '07:51:00' 5.75 0.0 234.4 24.6 0.0 39.0 17.0]
#  ['25/11/2010' '07:21:00' 5.074 0.24 238.55 21.4 1.0 2.0 18.0]]

# %%
import timeit
from matplotlib import pyplot as plt

x = []
y1= []
y2= []

for i in range (7):
    i = 10**(i)
    x.append(i)
    y1.append(timeit.timeit(f'filters_1_df(df[:{i}])' , number=100, globals=globals()))
    y2.append(timeit.timeit(f'filter_1_arr(array[:{i}])' , number=100, globals=globals()))
    
plt.plot(x,y1, label = 'pandas')
plt.plot(x,y2, label = 'numpy')
plt.xscale('log')
plt.legend()

# %%
def filters_2_df(df): 
    df_filtered_2 = df.loc[(df['Voltage'] > 235)]
    
    return df_filtered_2


filters_2_df(df)
# Out:
#                Date      Time    GAP    GRP  Voltage    GI  SM1  SM2   SM3
# 4        16/12/2006  17:28:00  3.666  0.528   235.68  15.8  0.0  1.0  17.0
# 5        16/12/2006  17:29:00  3.520  0.522   235.02  15.0  0.0  2.0  17.0
# 6        16/12/2006  17:30:00  3.702  0.520   235.09  15.8  0.0  1.0  17.0
# 7        16/12/2006  17:31:00  3.700  0.520   235.22  15.8  0.0  1.0  17.0
# 14       16/12/2006  17:38:00  4.054  0.422   235.24  17.6  0.0  1.0  17.0
# ...             ...       ...    ...    ...      ...   ...  ...  ...   ...
# 2075254  26/11/2010  20:58:00  0.946  0.000   240.43   4.0  0.0  0.0   0.0
# 2075255  26/11/2010  20:59:00  0.944  0.000   240.00   4.0  0.0  0.0   0.0
# 2075256  26/11/2010  21:00:00  0.938  0.000   239.82   3.8  0.0  0.0   0.0
# 2075257  26/11/2010  21:01:00  0.934  0.000   239.70   3.8  0.0  0.0   0.0
# 2075258  26/11/2010  21:02:00  0.932  0.000   239.55   3.8  0.0  0.0   0.0
#
# [1952491 rows x 9 columns]

# %%
def filter_2_arr(array):
    array_filtered_2 = array[array[:,4] > 235] #voltage > 23
    
    return array_filtered_2

print(filter_2_arr(array))
# Out:
# [['16/12/2006' '17:28:00' 3.6660000000000004 0.528 235.68 15.8 0.0 1.0
#   17.0]
#  ['16/12/2006' '17:29:00' 3.52 0.522 235.02 15.0 0.0 2.0 17.0]
#  ['16/12/2006' '17:30:00' 3.702 0.52 235.09 15.8 0.0 1.0 17.0]
#  ['16/12/2006' '17:31:00' 3.7 0.52 235.22 15.8 0.0 1.0 17.0]
#  ['16/12/2006' '17:38:00' 4.053999999999999 0.42200000000000004 235.24
#   17.6 0.0 1.0 17.0]
#  ...
#  ['26/11/2010' '20:58:00' 0.946 0.0 240.43 4.0 0.0 0.0 0.0]
#  ['26/11/2010' '20:59:00' 0.9440000000000001 0.0 240.0 4.0 0.0 0.0 0.0]
#  ['26/11/2010' '21:00:00' 0.938 0.0 239.82 3.8 0.0 0.0 0.0]
#  ['26/11/2010' '21:01:00' 0.934 0.0 239.7 3.8 0.0 0.0 0.0]
#  ['26/11/2010' '21:02:00' 0.932 0.0 239.55 3.8 0.0 0.0 0.0]]

# %%
x = []
y1= []
y2= []

for i in range (7):
    i = 10**(i)
    x.append(i)
    y1.append(timeit.timeit(f'filters_2_df(df[:{i}])' , number=100, globals=globals()))
    y2.append(timeit.timeit(f'filter_2_arr(array[:{i}])' , number=100, globals=globals()))
    
plt.plot(x,y1, label = 'pandas')
plt.plot(x,y2, label = 'numpy')
plt.xscale('log')
plt.legend()

# %%
def filters_3_df(df): 
    df_filtered_3 = df.loc[(df['GI'] >= 19) & (df['GI'] <= 20) & (df['SM2'] > df['SM3'])]
    
    return df_filtered_3

filters_3_df(df)
# Out:
#                Date      Time    GAP    GRP  Voltage    GI  SM1   SM2   SM3
# 45       16/12/2006  18:09:00  4.464  0.136   234.66  19.0  0.0  37.0  16.0
# 460      17/12/2006  01:04:00  4.582  0.258   238.08  19.6  0.0  13.0   0.0
# 464      17/12/2006  01:08:00  4.618  0.104   239.61  19.6  0.0  27.0   0.0
# 475      17/12/2006  01:19:00  4.636  0.140   237.37  19.4  0.0  36.0   0.0
# 476      17/12/2006  01:20:00  4.634  0.152   237.17  19.4  0.0  35.0   0.0
# ...             ...       ...    ...    ...      ...   ...  ...   ...   ...
# 2071589  24/11/2010  07:53:00  4.666  0.000   235.72  19.8  0.0  39.0  17.0
# 2071590  24/11/2010  07:54:00  4.694  0.000   236.78  19.8  0.0  39.0  18.0
# 2071591  24/11/2010  07:55:00  4.602  0.000   237.08  19.4  0.0  40.0  17.0
# 2071592  24/11/2010  07:56:00  4.536  0.000   237.03  19.0  0.0  39.0  17.0
# 2071593  24/11/2010  07:57:00  4.626  0.000   236.78  19.4  0.0  39.0  17.0
#
# [2509 rows x 9 columns]

# %%
def filter_3_arr(array):
    array_filtered_3 = array[(array[:,5] >= 19) & (array[:,5] <= 20) & 
                             (array[:,7] > array[:,8])] #19 <= GI <= 20; SM2 > SM3
    
    return array_filtered_3

print(filter_3_arr(array))
# Out:
# [['16/12/2006' '18:09:00' 4.4639999999999995 0.136 234.66 19.0 0.0 37.0
#   16.0]
#  ['17/12/2006' '01:04:00' 4.582 0.258 238.08 19.6 0.0 13.0 0.0]
#  ['17/12/2006' '01:08:00' 4.618 0.10400000000000001 239.61 19.6 0.0 27.0
#   0.0]
#  ['17/12/2006' '01:19:00' 4.636 0.14 237.37 19.4 0.0 36.0 0.0]
#  ['17/12/2006' '01:20:00' 4.6339999999999995 0.152 237.17 19.4 0.0 35.0
#   0.0]
#  ...
#  ['24/11/2010' '07:53:00' 4.666 0.0 235.72 19.8 0.0 39.0 17.0]
#  ['24/11/2010' '07:54:00' 4.694 0.0 236.78 19.8 0.0 39.0 18.0]
#  ['24/11/2010' '07:55:00' 4.602 0.0 237.08 19.4 0.0 40.0 17.0]
#  ['24/11/2010' '07:56:00' 4.5360000000000005 0.0 237.03 19.0 0.0 39.0
#   17.0]
#  ['24/11/2010' '07:57:00' 4.626 0.0 236.78 19.4 0.0 39.0 17.0]]

# %%
x = []
y1= []
y2= []

for i in range (7):
    i = 10**(i)
    x.append(i)
    y1.append(timeit.timeit(f'filters_3_df(df[:{i}])' , number=10, globals=globals()))
    y2.append(timeit.timeit(f'filter_3_arr(array[:{i}])' , number=10, globals=globals()))
    
plt.plot(x,y1, label = 'pandas')
plt.plot(x,y2, label = 'numpy')
plt.xscale('log')
plt.legend()

# %%
df = df.sample(500000)

def filter_mean_df(df):
    
    sm1_mean = df['SM1'].mean()
    sm2_mean = df['SM2'].mean()
    sm3_mean = df['SM3'].mean()
    
    return sm1_mean, sm2_mean, sm3_mean

print(filter_mean_df(df))
# Out:
# (1.122672, 1.29118, 6.473238)

# %%
rand_indexes = np.random.choice(array.shape[0], size = 500000, replace = False)
arr_filtered = array[rand_indexes]


def filter_mean_arr(arr_filtered):    
    
    sm_1_mean = np.mean(arr_filtered[:, 6])
    sm_2_mean = np.mean(arr_filtered[:, 7])
    sm_3_mean = np.mean(arr_filtered[:, 8])
    
    return sm_1_mean, sm_2_mean, sm_3_mean


print(filter_mean_arr(arr_filtered))
# Out:
# (1.117192, 1.296606, 6.460676)

# %%
x = []
y1= []
y2= []

for i in range (7):
    i = 10**(i)
    x.append(i)
    y1.append(timeit.timeit(f'filter_mean_df(df[:{i}])' , number=10, globals=globals()))
    y2.append(timeit.timeit(f'filter_mean_arr(arr_filtered[:{i}])' , number=10, globals=globals()))
    
plt.plot(x,y1, label = 'pandas')
plt.plot(x,y2, label = 'numpy')
plt.xscale('log')
plt.legend()

# %%
def split_df(df):
    
    df_filtered = df.loc[(df['Time'] >= '18:00:00') & (df['GAP'] >= 6) &
                                 (df['SM2'] > df['SM3']) & (df['SM2'] > df['SM1']), ]     

    r = len(df_filtered)
    
    df_1 = df_filtered[2:r // 2:3]
    df_2 = df_filtered[r // 2+1::4]
    
    return df_1, df_2

split_df(df)
# Out:
# (               Date      Time    GAP    GRP  Voltage    GI   SM1   SM2   SM3
#  1019698  23/11/2008  20:22:00  7.044  0.292   232.68  30.4   2.0  33.0  17.0
#  747549    18/5/2008  20:33:00  7.496  0.252   234.34  32.0   1.0  72.0  28.0
#  959215   12/10/2008  20:19:00  7.346  0.192   230.25  31.8   0.0  70.0  17.0
#  141208    24/3/2007  18:52:00  7.186  0.178   232.02  31.4   0.0  23.0  16.0
#  98146     22/2/2007  21:10:00  9.244  0.000   224.24  41.2  34.0  66.0  16.0
#  992365    4/11/2008  20:49:00  7.404  0.238   231.80  31.8   0.0  72.0  16.0
#  96621     21/2/2007  19:45:00  6.140  0.304   232.72  26.6   0.0  26.0   0.0
#  594855     2/2/2008  19:39:00  7.900  0.578   230.22  34.8  21.0  35.0  17.0
#  151363    31/3/2007  20:07:00  6.202  0.532   236.48  26.4   0.0  37.0  17.0
#  535784   23/12/2007  19:08:00  6.812  0.244   231.01  29.4   0.0  70.0   0.0
#  640873     5/3/2008  18:37:00  6.580  0.270   233.81  28.0   0.0  72.0   0.0
# ...

# %%
def split_arr(arr_filtered):
    
    arr_filtered = arr_filtered[(arr_filtered[:,1] > '18:00:00') & (arr_filtered[:,2] > 6) & 
                                (arr_filtered[:,7] > arr_filtered[:,6]) & (arr_filtered[:,7] > arr_filtered[:,8])]
    
    length = len(arr_filtered)
    
    arr_1 = arr_filtered[2:length//2:3] 
    arr_2 = arr_filtered[length//2+1::4] 

    return arr_1, arr_2

print (split_arr(arr_filtered))
# Out:
# (array([['24/11/2009', '19:41:00', 9.042, 0.37799999999999995, 233.28,
#         39.0, 36.0, 55.0, 18.0],
#        ['21/1/2007', '19:27:00', 7.5520000000000005, 0.25, 225.17, 33.4,
#         0.0, 66.0, 16.0],
#        ['17/4/2009', '20:46:00', 6.978, 0.23600000000000002, 236.67,
#         29.4, 0.0, 73.0, 18.0],
#        ['22/2/2007', '19:33:00', 6.178, 0.166, 231.73, 26.6, 0.0, 36.0,
#         17.0],
#        ['22/2/2007', '21:36:00', 6.206, 0.22, 229.67, 27.0, 1.0, 28.0,
#         16.0],
#        ['8/6/2008', '21:49:00', 6.837999999999999, 0.05, 235.1, 29.0,
#         0.0, 73.0, 18.0],
#        ['23/12/2007', '19:10:00', 6.763999999999999, 0.244, 231.21, 29.2,
#         0.0, 70.0, 0.0],
#        ['4/3/2007', '21:29:00', 6.854, 0.0, 233.34, 29.2, 0.0, 71.0,
#         16.0],
#        ['4/11/2008', '21:36:00', 6.9239999999999995, 0.258, 235.89, 29.2,
#         0.0, 73.0, 17.0],
#        ['15/2/2007', '19:35:00', 6.926, 0.6, 233.35, 29.8, 0.0, 36.0,
#         17.0],
# ...

# %%
x = []
y1= []
y2= []

for i in range (7):
    i = 10**(i)
    x.append(i)
    y1.append(timeit.timeit(f'split_df(df[:{i}])' , number=10, globals=globals()))
    y2.append(timeit.timeit(f'split_arr(arr_filtered[:{i}])' , number=10, globals=globals()))
    
plt.plot(x,y1, label = 'pandas')
plt.plot(x,y2, label = 'numpy')
plt.xscale('log')
plt.legend()
